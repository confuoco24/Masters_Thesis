806276197843765, 1900699723787668360, -1), (2920903420188101325, 6582932985078876615, 1900699723787668360, 1), (170263474824478188, 2734641253448378328, 1900699723787668360, 1), (6870735836185008482, 530978535661317918, 1900699723787668360, -1), (4489694174648242119, 4988022470467110298, 1900699723787668360, 1), (755058388019267673, 5033880255288063773, 1900699723787668360, 1), (9655878306376817862, 11390570952744396342, 1900699723787668360, -1), (8409078203788786970, 1599339035036226494, 1900699723787668360, -1), (1720307183657271198, 9555114274163877820, 1900699723787668360, -1), (8427746222082510956, 9757417417383403902, 1900699723787668360, -1), (8189931236214449880, 957610499689471274, 1900699723787668360, -1), (9648286748685986397, 8984471472005661083, 1900699723787668360, -1), (329166151113559885, 8429487124183816899, 1900699723787668360, -1), (9816971191501346199, 6159766766383536720, 1900699723787668360, 1), (2207500530490521221, 330527519626877435, 1900699723787668360, -1), (3884634565685168136, 8322662209636204519, 1900699723787668360, -1), (996888637069695635, 2633632652024697377, 1900699723787668360, 1), (5829739106092159460, 5188504815427662509, 1900699723787668360, 1), (8900658783207804961, 1326692123014042353, 1900699723787668360, -1), (909510054756871807, 7386277405086462418, 1900699723787668360, 1), (1036059354307972763, 10839512195686654763, 1900699723787668360, -1), (5918415241757052376, 10475795232933226175, 1900699723787668360, -1), (6782752241985472027, 5179020221973617182, 1900699723787668360, 1), (9963442062289985653, 5977641998023376196, 1900699723787668360, 1), (3407378754797428426, 92407841397025523, 1900699723787668360, -1), (4742373211532826715, 2473588147066814371, 1900699723787668360, 1), (7656944815616436354, 2656673731763007704, 1900699723787668360, 1), (8937902508049825812, 10862080721741724045, 1900699723787668360, -1), (1197125629297998152, 4249751756624559716, 1900699723787668360, 1), (4437934804396465194, 1926273129807478706, 1900699723787668360, 1), (6268950967384076921, 9838523046785443426, 1900699723787668360, -1), (3040019686433031828, 10356913108376096681, 1900699723787668360, -1)]

# %%
# PLOT DLP-64 DISTRIBUTION GRAPH

import matplotlib.pyplot as plt

# Separate data points and their classes
data_points = [(x, y) for x, y, _, label in generated_data]
classes = [label for _, _, _, label in generated_data]

# Plot each data point with different color based on its class
for point, label in zip(data_points, classes):
    color = 'red' if label == 1 else 'blue'
    plt.scatter(point[0], point[1], color=color)

plt.xlabel('x')
plt.ylabel('z')
plt.title('DLP-64 Dataset')

# Add legend for Class 1 and Class -1 outside the graph
plt.legend(handles=[plt.Line2D([], [], color='red', marker='o', linestyle='None', label='Class 1'),
                    plt.Line2D([], [], color='blue', marker='o', linestyle='None', label='Class -1')],
           loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
# DLP-64 QUANTUM EXPERIMENT (25 different seeds)

from sklearn.model_selection import train_test_split

random_seed = 1

while random_seed < 26:

    # PREPROCESSING

    # Split data into features (X) and labels (y)
    X = [(x, z, s) for x, z, s, label in generated_data]
    y = [label for x, z, s, label in generated_data]

    # Perform train-test split with 80% training and 20% testing
    sample_train, sample_test, label_train, label_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

    # Scale
    import numpy as np
    from sklearn.preprocessing import MinMaxScaler

    samples = np.append(sample_train, sample_test, axis=0)
    minmax_scale = MinMaxScaler((-1,1)).fit(samples)
    sample_train = minmax_scale.transform(sample_train)
    sample_test = minmax_scale.transform(sample_test)

    # Get backend
    from qiskit_ibm_runtime import QiskitRuntimeService, Session, Sampler
    service = QiskitRuntimeService(channel='ibm_quantum')

    backend = service.backends('ibmq_qasm_simulator')[0]
    print(backend)

    # QUANTUM SUPPORT VECTOR CLASSIFICATION

    from qiskit_algorithms.state_fidelities import ComputeUncompute
    from sklearn.metrics import classification_report, confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import time

    with Session(service = service, backend = backend):
        fidelity = ComputeUncompute(sampler=Sampler())

        # Create a new quantum kernel with the fidelity instance
        from qiskit.circuit.library import ZZFeatureMap
        from qiskit_machine_learning.kernels import FidelityQuantumKernel

        zz_map = ZZFeatureMap(feature_dimension=3, reps=2, entanglement='linear', insert_barriers=True)

        # Transpile circuit
        from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

        pm = generate_preset_pass_manager(optimization_level=1, target=backend.target)
        isa_circuit = pm.run(zz_map)

        # After qiskit update, instead of QuantumKernel class use the FidelityQuantumKernel class
        # In the new implementation we start from creating a fidelity instance. To create a fidelity instance we pass a sampler
        # The sampler in this example is from QiskitRuntimeService to leverage Qiskit runtime services
        zz_kernel = FidelityQuantumKernel(feature_map=isa_circuit, fidelity=fidelity)

        from qiskit_machine_learning.algorithms import QSVC

        qsvc = QSVC(quantum_kernel=zz_kernel)

        # Train quantum model
        start = time.time()
        qsvc.fit(sample_train, label_train)
        elapsed = time.time() - start

        # Predict on the test set
        predictions = qsvc.predict(sample_test)

        # Generate confusion matrix
        cm = confusion_matrix(label_test, predictions)

        # Calculate classification report
        report = classification_report(label_test, predictions, output_dict=True)

        # Extracting metrics from confusion matrix
        tn, fp, fn, tp = cm.ravel()
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        precision = tp / (tp + fp)
        recall = tp / (tp + fn)
        f1_score = 2 * (precision * recall) / (precision + recall)

        # Plot confusion matrix
        plt.figure(figsize=(3,2))
        sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", cbar=False,
                    xticklabels=['T', 'F'], yticklabels=['T', 'F'])
        plt.xlabel('Predicted')
        plt.ylabel('Real')
        plt.title(f'Quantum Kernel')
        plt.show()

        # Print results
        print(f"Time: {round(elapsed)} seconds")
        print(f"Accuracy: {accuracy:.2f}")
        print(f"Precision: {precision:.2f}")
        print(f"Recall: {recall:.2f}")
        print(f"F1 Score: {f1_score:.2f}\n")

    random_seed = random_seed + 1
# Out:
# <IBMBackend('ibmq_qasm_simulator')>
# Time: 1951 seconds
# Accuracy: 0.82
# Precision: 0.90
# Recall: 0.68
# F1 Score: 0.78
#
# <IBMBackend('ibmq_qasm_simulator')>
# Time: 1793 seconds
# Accuracy: 0.73
# Precision: 0.67
# Recall: 0.67
# F1 Score: 0.67
#
# <IBMBackend('ibmq_qasm_simulator')>
# Time: 1949 seconds
# Accuracy: 0.82
# Precision: 0.91
# Recall: 0.69
# F1 Score: 0.78
#
# <IBMBackend('ibmq_qasm_simulator')>
# Time: 1774 seconds
# Accuracy: 0.72
# Precision: 0.71
# Recall: 0.82
# F1 Score: 0.76
#
# <IBMBackend('ibmq_qasm_simulator')>
# Time: 1907 seconds
# Accuracy: 0.78
# Precision: 0.80
# Recall: 0.77
# F1 Score: 0.79
#
# <IBMBackend('ibmq_qasm_simulator')>
# Time: 1975 seconds
# Accuracy: 0.82
# Precision: 0.79
# Recall: 0.82
# F1 Score: 0.81
#
# <IBMBackend('ibmq_qasm_simulator')>
# Time: 1761 seconds
# Accuracy: 0.87
# Precision: 0.79
# Recall: 0.92
# F1 Score: 0.85
#
# <IBMBackend('ibmq_qasm_simulator')>
# Time: 1912 seconds
# Accuracy: 0.85
# Precision: 0.95
# ...

# %%
# DLP-64 CLASSICAL EXPERIMENT (25 different seeds)

from sklearn.model_selection import train_test_split

random_seed = 1

while random_seed < 26:

    # PREPROCESSING

    # Split data into features (X) and labels (y)
    X = [(x, z, s) for x, z, s, label in generated_data]
    y = [label for x, z, s, label in generated_data]

    # Perform train-test split with 80% training and 20% testing
    sample_train, sample_test, label_train, label_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

    # Scale
    import numpy as np
    from sklearn.preprocessing import MinMaxScaler

    samples = np.append(sample_train, sample_test, axis=0)
    minmax_scale = MinMaxScaler((-1,1)).fit(samples)
    sample_train = minmax_scale.transform(sample_train)
    sample_test = minmax_scale.transform(sample_test)

    # SUPPORT VECTOR CLASSIFICATION

    from sklearn.svm import SVC
    from sklearn.metrics import classification_report, confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import time

    # Set the style of seaborn
    sns.set(style="whitegrid")

    classical_kernels = ['linear', 'poly', 'rbf', 'sigmoid']
    print(f'----------------- Random Seed: {random_seed} ------------------')
    for kernel in classical_kernels:
        # Create SVC with the specified kernel
        classical_svc = SVC(kernel=kernel)

        # Train the SVC
        start = time.time()
        classical_svc.fit(sample_train, label_train)
        elapsed = time.time() - start

        # Predict on the test set
        predictions = classical_svc.predict(sample_test)

        # Calculate confusion matrix
        cm = confusion_matrix(label_test, predictions)

        # Calculate classification report
        report = classification_report(label_test, predictions, output_dict=True)

        # Extracting metrics from confusion matrix
        tn, fp, fn, tp = cm.ravel()
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        precision = tp / (tp + fp)
        recall = tp / (tp + fn)
        f1_score = 2 * (precision * recall) / (precision + recall)

        # Plot confusion matrix
        plt.figure(figsize=(3,2))
        sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", cbar=False,
                    xticklabels=['T', 'F'], yticklabels=['T', 'F'])
        plt.xlabel('Predicted')
        plt.ylabel('Real')
        plt.title(f'{kernel.capitalize()} Kernel')
        plt.show()

        # Print results
        print(f"Time: {round(elapsed)} seconds")
        print(f"Accuracy: {accuracy:.2f}")
        print(f"Precision: {precision:.2f}")
        print(f"Recall: {recall:.2f}")
        print(f"F1 Score: {f1_score:.2f}\n")

    random_seed = random_seed + 1
# Out:
# ----------------- Random Seed: 1 ------------------
# Time: 0 seconds
# Accuracy: 0.73
# Precision: 0.70
# Recall: 0.75
# F1 Score: 0.72
# Time: 0 seconds
# Accuracy: 0.50
# Precision: 0.43
# Recall: 0.21
# F1 Score: 0.29
# Time: 0 seconds
# Accuracy: 0.97
# Precision: 1.00
# Recall: 0.93
# F1 Score: 0.96
# Time: 0 seconds
# Accuracy: 0.62
# Precision: 0.58
# Recall: 0.68
# F1 Score: 0.62
#
# ----------------- Random Seed: 2 ------------------
# Time: 0 seconds
# Accuracy: 0.72
# Precision: 0.63
# Recall: 0.71
# F1 Score: 0.67
# Time: 0 seconds
# Accuracy: 0.52
# Precision: 0.35
# Recall: 0.25
# F1 Score: 0.29
# Time: 0 seconds
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# Time: 0 seconds
# Accuracy: 0.50
# Precision: 0.39
# Recall: 0.46
# F1 Score: 0.42
#
# ----------------- Random Seed: 3 ------------------
# Time: 0 seconds
# Accuracy: 0.73
# Precision: 0.70
# Recall: 0.79
# F1 Score: 0.74
# Time: 0 seconds
# Accuracy: 0.52
# Precision: 0.50
# Recall: 0.21
# ...
